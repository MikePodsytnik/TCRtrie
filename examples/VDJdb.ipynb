# %%
from tcrtrie import VDJdb

# %%
df = VDJdb.search( #return pandas.DataFrame
    query="CASSEGTDGYTF",
    maxSubstitution=2,
    maxInsertion=1,
    maxDeletion=1,
    maxEdits=2,
    vGeneFilter="TRBV19*01",
    jGeneFilter="TRBJ1-2*01",
    numThreads=8,
    detailed=True,
)
df
# Out:
#            query  target_index  distance    idx complex.id gene          cdr3  \
# 0   CASSEGTDGYTF         71355         2  71355      21271  TRB  CASSEGSYGYTF
# 1   CASSEGTDGYTF         55369         2  55369          0  TRB  CASSFGTWGYTF
# 2   CASSEGTDGYTF          1595         2   1595          0  TRB   CASSGTYGYTF
# 3   CASSEGTDGYTF         13272         2  13272          0  TRB  CASSIGTHGYTF
# 4   CASSEGTDGYTF         39777         2  39777          0  TRB  CASSIGTHGYTF
# 5   CASSEGTDGYTF         12585         2  12585          0  TRB  CASSIGTYGYTF
# 6   CASSEGTDGYTF         13759         2  13759       3666  TRB  CASSIGTYGYTF
# 7   CASSEGTDGYTF         39116         2  39116          0  TRB  CASSIGTYGYTF
# 8   CASSEGTDGYTF         42525         2  42525      13547  TRB  CASSIGTYGYTF
# 9   CASSEGTDGYTF         42738         2  42738          0  TRB  CASSIGTYGYTF
# 10  CASSEGTDGYTF         54897         2  54897          0  TRB  CASSIGTYGYTF
# 11  CASSEGTDGYTF         82707         2  82707      26947  TRB   CASSMGDGYTF
# 12  CASSEGTDGYTF         41010         2  41010          0  TRB  CASSVGTYGYTF
# 13  CASSEGTDGYTF         41031         2  41031          0  TRB  CASSVGTYGYTF
#
#        v.segm      j.segm      species  ...  \
# 0   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 1   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 2   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 3   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 4   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 5   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 6   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 7   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 8   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 9   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 10  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 11  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 12  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 13  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
#
#                                                  meta  \
# 0   {"study.id": "", "cell.subset": "", "subject.c...
# 1   {"study.id": "", "cell.subset": "CD8+", "subje...
# 2   {"study.id": "", "cell.subset": "CD8+", "subje...
# 3   {"study.id": "Child_Tcm", "cell.subset": "CD8+...
# 4   {"study.id": "Child", "cell.subset": "", "subj...
# 5   {"study.id": "Child_Tscm", "cell.subset": "CD8...
# 6   {"study.id": "Adult_Tcm", "cell.subset": "CD8+...
# 7   {"study.id": "Child", "cell.subset": "", "subj...
# 8   {"study.id": "Child", "cell.subset": "DAY7_Div...
# 9   {"study.id": "Child", "cell.subset": "DAY5_Div...
# 10  {"study.id": "", "cell.subset": "CD8+", "subje...
# 11  {"study.id": "", "cell.subset": "", "subject.c...
# 12  {"study.id": "Newborn", "cell.subset": "DAY10_...
# 13  {"study.id": "Newborn", "cell.subset": "DAY10_...
#
#                                               cdr3fix web.method  \
# 0   {"cdr3": "CASSEGSYGYTF", "cdr3_old": "CASSEGSY...       sort
# 1   {"cdr3": "CASSFGTWGYTF", "cdr3_old": "CASSFGTW...       sort
# 2   {"cdr3": "CASSGTYGYTF", "cdr3_old": "CASSGTYGY...       sort
# 3   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
# 4   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
# 5   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 6   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 7   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 8   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 9   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 10  {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 11  {"cdr3": "CASSMGDGYTF", "cdr3_old": "CASSMGDGY...       sort
# 12  {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
# 13  {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
#
#    web.method.seq web.cdr3fix.nc web.cdr3fix.unmp vdjdb.pgen.score  \
# 0      singlecell             no               no                3
# 1        amplicon             no               no                2
# 2        amplicon             no               no                3
# 3      singlecell             no               no                2
# 4      singlecell             no               no                2
# 5      singlecell             no               no                3
# 6      singlecell             no               no                3
# 7      singlecell             no               no                3
# 8      singlecell             no               no                3
# 9      singlecell             no               no                3
# 10       amplicon             no               no                3
# 11     singlecell             no               no                3
# 12     singlecell             no               no                3
# 13     singlecell             no               no                3
#
#    alignment_query alignment_cdr3  \
# 0     CASSEGTDGYTF   CASSEGSYGYTF
# 1     CASSEGTDGYTF   CASSFGTWGYTF
# 2     CASSEGTDGYTF   CASS-GTYGYTF
# 3     CASSEGTDGYTF   CASSIGTHGYTF
# 4     CASSEGTDGYTF   CASSIGTHGYTF
# 5     CASSEGTDGYTF   CASSIGTYGYTF
# 6     CASSEGTDGYTF   CASSIGTYGYTF
# 7     CASSEGTDGYTF   CASSIGTYGYTF
# 8     CASSEGTDGYTF   CASSIGTYGYTF
# 9     CASSEGTDGYTF   CASSIGTYGYTF
# 10    CASSEGTDGYTF   CASSIGTYGYTF
# 11    CASSEGTDGYTF   CASSMG-DGYTF
# 12    CASSEGTDGYTF   CASSVGTYGYTF
# 13    CASSEGTDGYTF   CASSVGTYGYTF
#
#                                        alignment_meta
# 0   {"distance": 2, "substitutions": 2, "insertion...
# 1   {"distance": 2, "substitutions": 2, "insertion...
# 2   {"distance": 2, "substitutions": 1, "insertion...
# 3   {"distance": 2, "substitutions": 2, "insertion...
# 4   {"distance": 2, "substitutions": 2, "insertion...
# 5   {"distance": 2, "substitutions": 2, "insertion...
# 6   {"distance": 2, "substitutions": 2, "insertion...
# 7   {"distance": 2, "substitutions": 2, "insertion...
# 8   {"distance": 2, "substitutions": 2, "insertion...
# 9   {"distance": 2, "substitutions": 2, "insertion...
# 10  {"distance": 2, "substitutions": 2, "insertion...
# 11  {"distance": 2, "substitutions": 1, "insertion...
# 12  {"distance": 2, "substitutions": 2, "insertion...
# 13  {"distance": 2, "substitutions": 2, "insertion...
#
# [14 rows x 30 columns]
