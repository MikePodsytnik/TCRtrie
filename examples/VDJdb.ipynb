# %%
from tcrtrie import VDJdb

# %%
df = VDJdb.search( #return pandas.DataFrame
    query="CASSEGTDGYTF",
    maxSubstitution=2,
    maxInsertion=1,
    maxDeletion=1,
    maxEdits=2,
    vGeneFilter="TRBV19*01",
    jGeneFilter="TRBJ1-2*01",
)
df
# Out:
#     distance complex.id gene          cdr3     v.segm      j.segm  \
# 12         2      21271  TRB  CASSEGSYGYTF  TRBV19*01  TRBJ1-2*01
# 0          2          0  TRB   CASSGTYGYTF  TRBV19*01  TRBJ1-2*01
# 6          2          0  TRB  CASSVGTYGYTF  TRBV19*01  TRBJ1-2*01
# 7          2          0  TRB  CASSVGTYGYTF  TRBV19*01  TRBJ1-2*01
# 11         2          0  TRB  CASSFGTWGYTF  TRBV19*01  TRBJ1-2*01
# 13         2      26947  TRB   CASSMGDGYTF  TRBV19*01  TRBJ1-2*01
# 1          2          0  TRB  CASSIGTYGYTF  TRBV19*01  TRBJ1-2*01
# 3          2       3666  TRB  CASSIGTYGYTF  TRBV19*01  TRBJ1-2*01
# 4          2          0  TRB  CASSIGTYGYTF  TRBV19*01  TRBJ1-2*01
# 8          2      13547  TRB  CASSIGTYGYTF  TRBV19*01  TRBJ1-2*01
# 9          2          0  TRB  CASSIGTYGYTF  TRBV19*01  TRBJ1-2*01
# 10         2          0  TRB  CASSIGTYGYTF  TRBV19*01  TRBJ1-2*01
# 2          2          0  TRB  CASSIGTHGYTF  TRBV19*01  TRBJ1-2*01
# 5          2          0  TRB  CASSIGTHGYTF  TRBV19*01  TRBJ1-2*01
#
#         species        mhc.a mhc.b mhc.class  ... vdjdb.score  \
# 12  HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           0
# 0   HomoSapiens  HLA-B*57:01   B2M      MHCI  ...           1
# 6   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           0
# 7   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           0
# 11  HomoSapiens     HLA-A*02   B2M      MHCI  ...           0
# 13  HomoSapiens  HLA-A*03:01   B2M      MHCI  ...           0
# 1   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           3
# 3   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           3
# 4   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           3
# 8   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           0
# 9   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           3
# 10  HomoSapiens     HLA-A*02   B2M      MHCI  ...           0
# 2   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           3
# 5   HomoSapiens  HLA-A*02:01   B2M      MHCI  ...           3
#
#                                              TCR_hash  \
# 12  407ad98235e203d89b13195e18aea7d1fcaa7db0bed502...
# 0
# 6
# 7
# 11
# 13  c0f2bb462ad55b329a6a7815e4c5e520e6eaea661d9a01...
# 1
# 3   5962155aa80190649a0fcc1c4bfeeaa23a64e1cb0c2217...
# 4
# 8   3045c2acad98563a839c911c5906b21bf4c72577263275...
# 9
# 10
# 2
# 5
#
#                                                method  \
# 12  {"identification": "dextramer-sort", "frequenc...
# 0   {"identification": "Tetramer-sort", "frequency...
# 6   {"identification": "peptide-stimulation, Cultu...
# 7   {"identification": "peptide-stimulation, Cultu...
# 11  {"identification": "antigen-loaded-targets,dex...
# 13  {"identification": "dextramer-sort", "frequenc...
# 1   {"identification": "tetramer.sort", "frequency...
# 3   {"identification": "tetramer.sort", "frequency...
# 4   {"identification": "tetramer-sort", "frequency...
# 8   {"identification": "peptide-stimulation, Cultu...
# 9   {"identification": "peptide-stimulation, Cultu...
# 10  {"identification": "antigen-loaded-targets,dex...
# 2   {"identification": "tetramer.sort", "frequency...
# 5   {"identification": "tetramer-sort", "frequency...
#
#                                                  meta  \
# 12  {"study.id": "", "cell.subset": "", "subject.c...
# 0   {"study.id": "", "cell.subset": "CD8+", "subje...
# 6   {"study.id": "Newborn", "cell.subset": "DAY10_...
# 7   {"study.id": "Newborn", "cell.subset": "DAY10_...
# 11  {"study.id": "", "cell.subset": "CD8+", "subje...
# 13  {"study.id": "", "cell.subset": "", "subject.c...
# 1   {"study.id": "Child_Tscm", "cell.subset": "CD8...
# 3   {"study.id": "Adult_Tcm", "cell.subset": "CD8+...
# 4   {"study.id": "Child", "cell.subset": "", "subj...
# 8   {"study.id": "Child", "cell.subset": "DAY7_Div...
# 9   {"study.id": "Child", "cell.subset": "DAY5_Div...
# 10  {"study.id": "", "cell.subset": "CD8+", "subje...
# 2   {"study.id": "Child_Tcm", "cell.subset": "CD8+...
# 5   {"study.id": "Child", "cell.subset": "", "subj...
#
#                                               cdr3fix web.method  \
# 12  {"cdr3": "CASSEGSYGYTF", "cdr3_old": "CASSEGSY...       sort
# 0   {"cdr3": "CASSGTYGYTF", "cdr3_old": "CASSGTYGY...       sort
# 6   {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
# 7   {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
# 11  {"cdr3": "CASSFGTWGYTF", "cdr3_old": "CASSFGTW...       sort
# 13  {"cdr3": "CASSMGDGYTF", "cdr3_old": "CASSMGDGY...       sort
# 1   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 3   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 4   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 8   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 9   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 10  {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 2   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
# 5   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
#
#    web.method.seq web.cdr3fix.nc web.cdr3fix.unmp vdjdb.pgen.score
# 12     singlecell             no               no                3
# 0        amplicon             no               no                3
# 6      singlecell             no               no                3
# 7      singlecell             no               no                3
# 11       amplicon             no               no                2
# 13     singlecell             no               no                3
# 1      singlecell             no               no                3
# 3      singlecell             no               no                3
# 4      singlecell             no               no                3
# 8      singlecell             no               no                3
# 9      singlecell             no               no                3
# 10       amplicon             no               no                3
# 2      singlecell             no               no                2
# 5      singlecell             no               no                2
#
# [14 rows x 24 columns]
