# %%
from tcrtrie import VDJdb

# %%
df = VDJdb.search( #return pandas.DataFrame
    query="CASSEGTDGYTF",
    maxSubstitution=2,
    maxInsertion=1,
    maxDeletion=1,
    maxEdits=2,
    vGeneFilter="TRBV19*01",
    jGeneFilter="TRBJ1-2*01",
    numThreads=8,
    detailed=True,
)
df
# Out:
#            query  target_index  distance    idx complex.id gene          cdr3  \
# 0   CASSEGTDGYTF         71355         2  71355      21271  TRB  CASSEGSYGYTF
# 1   CASSEGTDGYTF         55369         2  55369          0  TRB  CASSFGTWGYTF
# 2   CASSEGTDGYTF          1595         2   1595          0  TRB   CASSGTYGYTF
# 3   CASSEGTDGYTF         13272         2  13272          0  TRB  CASSIGTHGYTF
# 4   CASSEGTDGYTF         39777         2  39777          0  TRB  CASSIGTHGYTF
# 5   CASSEGTDGYTF         12585         2  12585          0  TRB  CASSIGTYGYTF
# 6   CASSEGTDGYTF         13759         2  13759       3666  TRB  CASSIGTYGYTF
# 7   CASSEGTDGYTF         39116         2  39116          0  TRB  CASSIGTYGYTF
# 8   CASSEGTDGYTF         42525         2  42525      13547  TRB  CASSIGTYGYTF
# 9   CASSEGTDGYTF         42738         2  42738          0  TRB  CASSIGTYGYTF
# 10  CASSEGTDGYTF         54897         2  54897          0  TRB  CASSIGTYGYTF
# 11  CASSEGTDGYTF         82707         2  82707      26947  TRB   CASSMGDGYTF
# 12  CASSEGTDGYTF         41010         2  41010          0  TRB  CASSVGTYGYTF
# 13  CASSEGTDGYTF         41031         2  41031          0  TRB  CASSVGTYGYTF
#
#        v.segm      j.segm      species  ...  \
# 0   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 1   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 2   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 3   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 4   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 5   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 6   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 7   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 8   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 9   TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 10  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 11  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 12  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
# 13  TRBV19*01  TRBJ1-2*01  HomoSapiens  ...
#
#                                                  meta  \
# 0   {"study.id": "", "cell.subset": "", "subject.c...
# 1   {"study.id": "", "cell.subset": "CD8+", "subje...
# 2   {"study.id": "", "cell.subset": "CD8+", "subje...
# 3   {"study.id": "Child_Tcm", "cell.subset": "CD8+...
# 4   {"study.id": "Child", "cell.subset": "", "subj...
# 5   {"study.id": "Child_Tscm", "cell.subset": "CD8...
# 6   {"study.id": "Adult_Tcm", "cell.subset": "CD8+...
# 7   {"study.id": "Child", "cell.subset": "", "subj...
# 8   {"study.id": "Child", "cell.subset": "DAY7_Div...
# 9   {"study.id": "Child", "cell.subset": "DAY5_Div...
# 10  {"study.id": "", "cell.subset": "CD8+", "subje...
# 11  {"study.id": "", "cell.subset": "", "subject.c...
# 12  {"study.id": "Newborn", "cell.subset": "DAY10_...
# 13  {"study.id": "Newborn", "cell.subset": "DAY10_...
#
#                                               cdr3fix web.method  \
# 0   {"cdr3": "CASSEGSYGYTF", "cdr3_old": "CASSEGSY...       sort
# 1   {"cdr3": "CASSFGTWGYTF", "cdr3_old": "CASSFGTW...       sort
# 2   {"cdr3": "CASSGTYGYTF", "cdr3_old": "CASSGTYGY...       sort
# 3   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
# 4   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
# 5   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 6   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 7   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 8   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 9   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 10  {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 11  {"cdr3": "CASSMGDGYTF", "cdr3_old": "CASSMGDGY...       sort
# 12  {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
# 13  {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
#
#    web.method.seq web.cdr3fix.nc web.cdr3fix.unmp vdjdb.pgen.score  \
# 0      singlecell             no               no                3
# 1        amplicon             no               no                2
# 2        amplicon             no               no                3
# 3      singlecell             no               no                2
# 4      singlecell             no               no                2
# 5      singlecell             no               no                3
# 6      singlecell             no               no                3
# 7      singlecell             no               no                3
# 8      singlecell             no               no                3
# 9      singlecell             no               no                3
# 10       amplicon             no               no                3
# 11     singlecell             no               no                3
# 12     singlecell             no               no                3
# 13     singlecell             no               no                3
#
#    alignment_query alignment_cdr3  \
# 0     CASSEGTDGYTF   CASSEGSYGYTF
# 1     CASSEGTDGYTF   CASSFGTWGYTF
# 2     CASSEGTDGYTF   CASS-GTYGYTF
# 3     CASSEGTDGYTF   CASSIGTHGYTF
# 4     CASSEGTDGYTF   CASSIGTHGYTF
# 5     CASSEGTDGYTF   CASSIGTYGYTF
# 6     CASSEGTDGYTF   CASSIGTYGYTF
# 7     CASSEGTDGYTF   CASSIGTYGYTF
# 8     CASSEGTDGYTF   CASSIGTYGYTF
# 9     CASSEGTDGYTF   CASSIGTYGYTF
# 10    CASSEGTDGYTF   CASSIGTYGYTF
# 11    CASSEGTDGYTF   CASSMG-DGYTF
# 12    CASSEGTDGYTF   CASSVGTYGYTF
# 13    CASSEGTDGYTF   CASSVGTYGYTF
#
#                                        alignment_meta
# 0   {"distance": 2, "substitutions": 2, "insertion...
# 1   {"distance": 2, "substitutions": 2, "insertion...
# 2   {"distance": 2, "substitutions": 1, "insertion...
# 3   {"distance": 2, "substitutions": 2, "insertion...
# 4   {"distance": 2, "substitutions": 2, "insertion...
# 5   {"distance": 2, "substitutions": 2, "insertion...
# 6   {"distance": 2, "substitutions": 2, "insertion...
# 7   {"distance": 2, "substitutions": 2, "insertion...
# 8   {"distance": 2, "substitutions": 2, "insertion...
# 9   {"distance": 2, "substitutions": 2, "insertion...
# 10  {"distance": 2, "substitutions": 2, "insertion...
# 11  {"distance": 2, "substitutions": 1, "insertion...
# 12  {"distance": 2, "substitutions": 2, "insertion...
# 13  {"distance": 2, "substitutions": 2, "insertion...
#
# [14 rows x 30 columns]

# %%
VDJdb.searchForAll(
    queries=["CASSEGTDGYTF", "CAISTGDSNQPQHF"],
    maxSubstitution=2,
    maxInsertion=1,
    maxDeletion=1,
    maxEdits=2,
    vGeneFilters=["TRBV19*01", "TRBV6-6*01"],
    jGeneFilters=["TRBJ1-2*01", "TRBJ1-5*01"],
    numThreads=8,
    detailed=True,
)
# Out:
#     query_index           query  target_index  distance    idx complex.id  \
# 0             0    CASSEGTDGYTF         71355         2  71355      21271
# 1             0    CASSEGTDGYTF         55369         2  55369          0
# 2             0    CASSEGTDGYTF          1595         2   1595          0
# 3             0    CASSEGTDGYTF         13272         2  13272          0
# 4             0    CASSEGTDGYTF         39777         2  39777          0
# 5             0    CASSEGTDGYTF         12585         2  12585          0
# 6             0    CASSEGTDGYTF         13759         2  13759       3666
# 7             0    CASSEGTDGYTF         39116         2  39116          0
# 8             0    CASSEGTDGYTF         42525         2  42525      13547
# 9             0    CASSEGTDGYTF         42738         2  42738          0
# 10            0    CASSEGTDGYTF         54897         2  54897          0
# 11            0    CASSEGTDGYTF         82707         2  82707      26947
# 12            0    CASSEGTDGYTF         41010         2  41010          0
# 13            0    CASSEGTDGYTF         41031         2  41031          0
# 14            1  CAISTGDSNQPQHF           240         0    240          0
# 15            1  CAISTGDSNQPQHF         63637         2  63637      17412
# 16            1  CAISTGDSNQPQHF           238         2    238          0
#
#    gene             cdr3      v.segm      j.segm  ...  \
# 0   TRB     CASSEGSYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 1   TRB     CASSFGTWGYTF   TRBV19*01  TRBJ1-2*01  ...
# 2   TRB      CASSGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 3   TRB     CASSIGTHGYTF   TRBV19*01  TRBJ1-2*01  ...
# 4   TRB     CASSIGTHGYTF   TRBV19*01  TRBJ1-2*01  ...
# 5   TRB     CASSIGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 6   TRB     CASSIGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 7   TRB     CASSIGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 8   TRB     CASSIGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 9   TRB     CASSIGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 10  TRB     CASSIGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 11  TRB      CASSMGDGYTF   TRBV19*01  TRBJ1-2*01  ...
# 12  TRB     CASSVGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 13  TRB     CASSVGTYGYTF   TRBV19*01  TRBJ1-2*01  ...
# 14  TRB   CAISTGDSNQPQHF  TRBV6-6*01  TRBJ1-5*01  ...
# 15  TRB   CASNTGDSNQPQHF  TRBV6-6*01  TRBJ1-5*01  ...
# 16  TRB  CASSTGDHSNQPQHF  TRBV6-6*01  TRBJ1-5*01  ...
#
#                                                  meta  \
# 0   {"study.id": "", "cell.subset": "", "subject.c...
# 1   {"study.id": "", "cell.subset": "CD8+", "subje...
# 2   {"study.id": "", "cell.subset": "CD8+", "subje...
# 3   {"study.id": "Child_Tcm", "cell.subset": "CD8+...
# 4   {"study.id": "Child", "cell.subset": "", "subj...
# 5   {"study.id": "Child_Tscm", "cell.subset": "CD8...
# 6   {"study.id": "Adult_Tcm", "cell.subset": "CD8+...
# 7   {"study.id": "Child", "cell.subset": "", "subj...
# 8   {"study.id": "Child", "cell.subset": "DAY7_Div...
# 9   {"study.id": "Child", "cell.subset": "DAY5_Div...
# 10  {"study.id": "", "cell.subset": "CD8+", "subje...
# 11  {"study.id": "", "cell.subset": "", "subject.c...
# 12  {"study.id": "Newborn", "cell.subset": "DAY10_...
# 13  {"study.id": "Newborn", "cell.subset": "DAY10_...
# 14  {"study.id": "", "cell.subset": "CD8+", "subje...
# 15  {"study.id": "", "cell.subset": "", "subject.c...
# 16  {"study.id": "", "cell.subset": "CD8+", "subje...
#
#                                               cdr3fix web.method  \
# 0   {"cdr3": "CASSEGSYGYTF", "cdr3_old": "CASSEGSY...       sort
# 1   {"cdr3": "CASSFGTWGYTF", "cdr3_old": "CASSFGTW...       sort
# 2   {"cdr3": "CASSGTYGYTF", "cdr3_old": "CASSGTYGY...       sort
# 3   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
# 4   {"cdr3": "CASSIGTHGYTF", "cdr3_old": "CASSIGTH...       sort
# 5   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 6   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 7   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 8   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 9   {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 10  {"cdr3": "CASSIGTYGYTF", "cdr3_old": "CASSIGTY...       sort
# 11  {"cdr3": "CASSMGDGYTF", "cdr3_old": "CASSMGDGY...       sort
# 12  {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
# 13  {"cdr3": "CASSVGTYGYTF", "cdr3_old": "CASSVGTY...       sort
# 14  {"cdr3": "CAISTGDSNQPQHF", "cdr3_old": "CAISTG...       sort
# 15  {"cdr3": "CASNTGDSNQPQHF", "cdr3_old": "CASNTG...       sort
# 16  {"cdr3": "CASSTGDHSNQPQHF", "cdr3_old": "CASST...       sort
#
#    web.method.seq web.cdr3fix.nc web.cdr3fix.unmp vdjdb.pgen.score  \
# 0      singlecell             no               no                3
# 1        amplicon             no               no                2
# 2        amplicon             no               no                3
# 3      singlecell             no               no                2
# 4      singlecell             no               no                2
# 5      singlecell             no               no                3
# 6      singlecell             no               no                3
# 7      singlecell             no               no                3
# 8      singlecell             no               no                3
# 9      singlecell             no               no                3
# 10       amplicon             no               no                3
# 11     singlecell             no               no                3
# 12     singlecell             no               no                3
# 13     singlecell             no               no                3
# 14       amplicon             no               no                2
# 15     singlecell             no               no                2
# 16       amplicon             no               no                2
#
#     alignment_query   alignment_cdr3  \
# 0      CASSEGTDGYTF     CASSEGSYGYTF
# 1      CASSEGTDGYTF     CASSFGTWGYTF
# 2      CASSEGTDGYTF     CASS-GTYGYTF
# 3      CASSEGTDGYTF     CASSIGTHGYTF
# 4      CASSEGTDGYTF     CASSIGTHGYTF
# 5      CASSEGTDGYTF     CASSIGTYGYTF
# 6      CASSEGTDGYTF     CASSIGTYGYTF
# 7      CASSEGTDGYTF     CASSIGTYGYTF
# 8      CASSEGTDGYTF     CASSIGTYGYTF
# 9      CASSEGTDGYTF     CASSIGTYGYTF
# 10     CASSEGTDGYTF     CASSIGTYGYTF
# 11     CASSEGTDGYTF     CASSMG-DGYTF
# 12     CASSEGTDGYTF     CASSVGTYGYTF
# 13     CASSEGTDGYTF     CASSVGTYGYTF
# 14   CAISTGDSNQPQHF   CAISTGDSNQPQHF
# 15   CAISTGDSNQPQHF   CASNTGDSNQPQHF
# 16  CAISTGD-SNQPQHF  CASSTGDHSNQPQHF
#
#                                        alignment_meta
# 0   {"distance": 2, "substitutions": 2, "insertion...
# 1   {"distance": 2, "substitutions": 2, "insertion...
# 2   {"distance": 2, "substitutions": 1, "insertion...
# 3   {"distance": 2, "substitutions": 2, "insertion...
# 4   {"distance": 2, "substitutions": 2, "insertion...
# 5   {"distance": 2, "substitutions": 2, "insertion...
# 6   {"distance": 2, "substitutions": 2, "insertion...
# 7   {"distance": 2, "substitutions": 2, "insertion...
# 8   {"distance": 2, "substitutions": 2, "insertion...
# 9   {"distance": 2, "substitutions": 2, "insertion...
# 10  {"distance": 2, "substitutions": 2, "insertion...
# 11  {"distance": 2, "substitutions": 1, "insertion...
# 12  {"distance": 2, "substitutions": 2, "insertion...
# 13  {"distance": 2, "substitutions": 2, "insertion...
# 14  {"distance": 0, "substitutions": 0, "insertion...
# 15  {"distance": 2, "substitutions": 2, "insertion...
# 16  {"distance": 2, "substitutions": 1, "insertion...
#
# [17 rows x 31 columns]

# %%
VDJdb.searchWithMatrix( #BLOSUM62 is used by default
    query="CASSEGTDGYTF",
    maxCost=12,
    detailed=True,
)
# Out:
#           query  target_index  cost    idx complex.id gene          cdr3  \
# 0  CASSEGTDGYTF         36919  12.0  36919          0  TRB  CASSEGPSGYTF
# 1  CASSEGTDGYTF         99885   0.0  99885      35536  TRB  CASSEGTDGYTF
# 2  CASSEGTDGYTF         50267  11.5  50267          0  TRB  CASSHGTSGYTF
# 3  CASSEGTDGYTF         79681  10.5  79681      25434  TRB  CASSQGGDGYTF
# 4  CASSEGTDGYTF         59325  11.0  59325      15399  TRB  CASSWGTDGYTF
#
#         v.segm      j.segm      species  ...  \
# 0     TRBV9*01  TRBJ1-2*01  HomoSapiens  ...
# 1   TRBV4-1*01  TRBJ1-2*01  HomoSapiens  ...
# 2   TRBV4-2*01  TRBJ1-2*01  HomoSapiens  ...
# 3   TRBV4-1*01  TRBJ1-2*01  HomoSapiens  ...
# 4  TRBV11-2*01  TRBJ1-2*01  HomoSapiens  ...
#
#                                                 meta  \
# 0  {"study.id": "", "cell.subset": "CD8+", "subje...
# 1  {"study.id": "", "cell.subset": "", "subject.c...
# 2  {"study.id": "", "cell.subset": "CD8+", "subje...
# 3  {"study.id": "", "cell.subset": "", "subject.c...
# 4  {"study.id": "", "cell.subset": "CD8+", "subje...
#
#                                              cdr3fix web.method  \
# 0  {"cdr3": "CASSEGPSGYTF", "cdr3_old": "CASSEGPS...       sort
# 1  {"cdr3": "CASSEGTDGYTF", "cdr3_old": "CASSEGTD...       sort
# 2  {"cdr3": "CASSHGTSGYTF", "cdr3_old": "CASSHGTS...       sort
# 3  {"cdr3": "CASSQGGDGYTF", "cdr3_old": "CASSQGGD...       sort
# 4  {"cdr3": "CASSWGTDGYTF", "cdr3_old": "CASSWGTD...       sort
#
#   web.method.seq web.cdr3fix.nc web.cdr3fix.unmp vdjdb.pgen.score  \
# 0         sanger             no               no                2
# 1     singlecell             no               no                3
# 2       amplicon             no               no                2
# 3     singlecell             no               no                3
# 4     singlecell             no               no                3
#
#   alignment_query alignment_cdr3  \
# 0    CASSEGTDGYTF   CASSEGPSGYTF
# 1    CASSEGTDGYTF   CASSEGTDGYTF
# 2    CASSEGTDGYTF   CASSHGTSGYTF
# 3    CASSEGTDGYTF   CASSQGGDGYTF
# 4    CASSEGTDGYTF   CASSWGTDGYTF
#
#                                       alignment_meta
# 0  {"distance": 12, "substitutions": 2, "insertio...
# 1  {"distance": 0, "substitutions": 0, "insertion...
# 2  {"distance": 11.5, "substitutions": 2, "insert...
# 3  {"distance": 10.5, "substitutions": 2, "insert...
# 4  {"distance": 11, "substitutions": 1, "insertio...
#
# [5 rows x 30 columns]

# %%
VDJdb.printMatrix()
# Out:
#          -     A     C     D     E     F     G     H     I     K     L     M     N     P     Q     R     S     T     V     W     Y
#    -  0.00  8.00 18.00 12.00 10.00 12.00 12.00 16.00  8.00 10.00  8.00 10.00 12.00 14.00 10.00 10.00  8.00 10.00  8.00 22.00 14.00
#    A  8.00  0.00  6.50  7.00  5.50  7.00  5.00  8.00  5.00  5.50  5.00  5.50  7.00  6.50  5.50  5.50  3.00  4.50  4.00 10.50  7.50
#    C 18.00  6.50  0.00 10.50 11.00  9.50 10.50 11.50  7.50 10.00  7.50  8.00 10.50 11.00 10.00 10.00  7.50  8.00  7.50 12.00 10.00
#    D 12.00  7.00 10.50  0.00  3.50  9.00  7.00  8.00  8.00  6.50  9.00  8.50  5.00  7.50  5.50  7.50  5.00  6.50  8.00 12.50  9.50
#    E 10.00  5.50 11.00  3.50  0.00  8.50  7.50  6.50  7.50  4.00  7.50  7.00  5.50  7.00  3.00  5.00  4.50  6.00  6.50 11.00  8.00
#    F 12.00  7.00  9.50  9.00  8.50  0.00  9.00  8.00  5.00  8.50  5.00  5.50  9.00 10.50  8.50  8.50  7.00  7.50  6.00  7.50  3.50
#    G 12.00  5.00 10.50  7.00  7.50  9.00  0.00  9.00  9.00  7.50  9.00  8.50  6.00  8.50  7.50  7.50  5.00  7.50  8.00 10.50  9.50
#    H 16.00  8.00 11.50  8.00  6.50  8.00  9.00  0.00  9.00  7.50  9.00  8.50  6.00  9.50  6.50  6.50  7.00  8.50  9.00 11.50  5.50
#    I  8.00  5.00  7.50  8.00  7.50  5.00  9.00  9.00  0.00  7.50  2.00  3.50  8.00  8.50  7.50  7.50  6.00  5.50  1.00 10.50  6.50
#    K 10.00  5.50 10.00  6.50  4.00  8.50  7.50  7.50  7.50  0.00  6.50  6.00  5.50  7.00  4.00  3.00  4.50  6.00  6.50 11.00  8.00
#    L  8.00  5.00  7.50  9.00  7.50  5.00  9.00  9.00  2.00  6.50  0.00  2.50  8.00  8.50  6.50  6.50  6.00  5.50  3.00  9.50  6.50
#    M 10.00  5.50  8.00  8.50  7.00  5.50  8.50  8.50  3.50  6.00  2.50  0.00  7.50  8.00  5.00  6.00  5.50  6.00  3.50  9.00  7.00
#    N 12.00  7.00 10.50  5.00  5.50  9.00  6.00  6.00  8.00  5.50  8.00  7.50  0.00  8.50  5.50  5.50  4.00  5.50  8.00 12.50  8.50
#    P 14.00  6.50 11.00  7.50  7.00 10.50  8.50  9.50  8.50  7.00  8.50  8.00  8.50  0.00  7.00  8.00  6.50  7.00  7.50 13.00 10.00
#    Q 10.00  5.50 10.00  5.50  3.00  8.50  7.50  6.50  7.50  4.00  6.50  5.00  5.50  7.00  0.00  4.00  4.50  6.00  6.50 10.00  7.00
#    R 10.00  5.50 10.00  7.50  5.00  8.50  7.50  6.50  7.50  3.00  6.50  6.00  5.50  8.00  4.00  0.00  5.50  6.00  7.50 11.00  8.00
#    S  8.00  3.00  7.50  5.00  4.50  7.00  5.00  7.00  6.00  4.50  6.00  5.50  4.00  6.50  4.50  5.50  0.00  3.50  6.00 10.50  7.50
#    T 10.00  4.50  8.00  6.50  6.00  7.50  7.50  8.50  5.50  6.00  5.50  6.00  5.50  7.00  6.00  6.00  3.50  0.00  4.50 10.00  8.00
#    V  8.00  4.00  7.50  8.00  6.50  6.00  8.00  9.00  1.00  6.50  3.00  3.50  8.00  7.50  6.50  7.50  6.00  4.50  0.00 10.50  6.50
#    W 22.00 10.50 12.00 12.50 11.00  7.50 10.50 11.50 10.50 11.00  9.50  9.00 12.50 13.00 10.00 11.00 10.50 10.00 10.50  0.00  7.00
#    Y 14.00  7.50 10.00  9.50  8.00  3.50  9.50  5.50  6.50  8.00  6.50  7.00  8.50 10.00  7.00  8.00  7.50  8.00  6.50  7.00  0.00
